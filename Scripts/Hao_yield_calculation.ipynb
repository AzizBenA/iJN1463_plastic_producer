# %%
import jupyter_utils as ju

# %% [markdown]
# # Loading model

# %%
model = ju.load_model("Experiment", "250709_iJN1463_updated_5.sbml")

# %%
model.reactions.get_by_id('SK_adpac_c').bounds = -3.3350, 0.0
model.reactions.get_by_id('SK_14btdl_c').bounds = -1.6675, 0.0
model.reactions.get_by_id('SK_etheglycol_c').bounds = -3.3175, 0.0
model.reactions.get_by_id('SK_terepa_c').bounds = -1.65, 0.0
model.reactions.get_by_id('EX_h2s_e').bounds = -0.0, 0.0

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 SK_bhb_c = 2.5000000000000044</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>13.75</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>etheglycol_c</td>
#       <td>SK_etheglycol_c</td>
#       <td>10</td>
#       <td>2</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>-10</td>
#       <td>1</td>
#       <td>50.00%</td>
#     </tr>
#     <tr>
#       <td>h2o_e</td>
#       <td>EX_h2o_e</td>
#       <td>-20</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>h_e</td>
#       <td>EX_h_e</td>
#       <td>-2.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>bhb_c</td>
#       <td>SK_bhb_c</td>
#       <td>-2.5</td>
#       <td>4</td>
#       <td>50.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# added a sink reaction for BHB

# %%
model.add_boundary(model.metabolites.get_by_id('bhb_c'), type='sink',lb=0.0, ub=1000)
# Out:
# <Reaction SK_bhb_c at 0x1994ac4cd10>

# %% [markdown]
# # Calculate the carbon yield for each monomer

# %%
# substrate carbon number
substrate_carbons = {
    'SK_etheglycol_c': 2,
    'SK_terepa_c': 8,
    'SK_adpac_c': 6,
    'SK_14btdl_c': 4
}
model.objective='SK_bhb_c'
model.optimize()
total_sub_cflux = 0
for rxn_id in substrate_carbons:
    upt = -model.reactions.get_by_id(rxn_id).flux  # uptake positive magnitude
    print(f'{rxn_id} flux = {upt}')
    total_sub_cflux += upt * substrate_carbons[rxn_id]
prod_flux = model.reactions.get_by_id('SK_bhb_c').flux
prod_cflux = prod_flux * 4  # BHB has 4 carbons
carbon_yield = prod_cflux / total_sub_cflux if total_sub_cflux > 0 else None
print(carbon_yield)
# Out:
# SK_etheglycol_c flux = 3.3175
# SK_terepa_c flux = 1.65
# SK_adpac_c flux = 3.335
# SK_14btdl_c flux = 1.6675
# 0.5716973019456085

# %%
product_flux =  model.reactions.get_by_id('SK_bhb_c').flux
substrat_flux = - model.reactions.get_by_id('SK_adpac_c').flux


yield_flux = (product_flux*4)/(substrat_flux*6)
yield_flux
# Out:
# 1.3289605197401144

# %% [markdown]
# check the summary of metabolite

# %%
summary = model.metabolites.get_by_id('14btdl_c').summary()
summary
# Out:
# <h3>14btdl_c</h3><p>C4H10O2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # Reactions knocked out for correct yield

# %%
model.reactions.get_by_id('SUCOAS').bounds = -1000.0, 0.0 
model.reactions.get_by_id('PPC').bounds = -0.0, 1000.0 # OPEN
model.reactions.get_by_id('PC').bounds = -0.0, 1000.0 # OPEN
model.reactions.get_by_id('THRS').bounds = -0.0, 0.0

# %% [markdown]
# check reaction information

# %%
search_word = 'PC'

for reaction in model.reactions:
    if search_word == reaction.id:
        print(f"Reaction ID: {reaction.id}")
        print(f"Name: {reaction.name}")
        print(f"Equation: {reaction.reaction}")
        print(f"Lower Bound: {reaction.lower_bound}")
        print(f"Upper Bound: {reaction.upper_bound}")
        print(reaction.annotation)
        print(f"Genes: {[gene.id for gene in reaction.genes]}")
# Out:
# Reaction ID: PC
# Name: Pyruvate carboxylase
# Equation: atp_c + hco3_c + pyr_c --> adp_c + h_c + oaa_c + pi_c
# Lower Bound: 0.0
# Upper Bound: 999999.0
# {'sbo': 'SBO:0000176', 'bigg.reaction': 'PC', 'biocyc': 'META:PYRUVATE-CARBOXYLASE-RXN', 'ec-code': '6.4.1.1', 'kegg.reaction': 'R00344', 'metanetx.reaction': 'MNXR102391', 'rhea': ['20847', '20844', '20845', '20846'], 'sabiork': '105', 'seed.reaction': 'rxn00250'}
# Genes: ['PP_5347', 'PP_5346']

# %% [markdown]
# check metabolite information

# %%
search_word = 'bhb'
# Iterate over metabolites in the model
for metabolite in model.metabolites:
    if search_word in metabolite.id:
        # Print metabolite information
        print(metabolite.id)
        print(metabolite.charge)
        print(metabolite.formula)
        print(metabolite.name)
        print(metabolite.compartment)
        print(metabolite.annotation)
        
        # Get related reactions
        related_reactions = list(metabolite.reactions)
        
        # Get genes related to the reactions
        related_genes = set()
        for reaction in related_reactions:
            related_genes.update(reaction.genes)
        
        # Print related reactions and associated genes
        print(f"Related Reactions: {', '.join(r.id for r in related_reactions)}")
        print(f"Genes Associated: {', '.join(g.id for g in related_genes)}\n")
# Out:
# bhb_c
# -1
# C4H7O3
# (R)-3-Hydroxybutanoate
# c
# {'sbo': 'SBO:0000247', 'bigg.metabolite': 'bhb', 'biocyc': 'META:CPD-335', 'chebi': ['CHEBI:18666', 'CHEBI:10983', 'CHEBI:17066', 'CHEBI:322'], 'hmdb': 'HMDB00011', 'inchi_key': 'WHBMMWSBFZVSSR-GSVOUGTGSA-M', 'kegg.compound': 'C01089', 'lipidmaps': 'LMFA01050243', 'metanetx.chemical': 'MNXM663', 'reactome.compound': ['73911', '5696461'], 'sabiork': '2245', 'seed.compound': 'cpd00797'}
# Related Reactions: RHA40tpp, BDH, SK_bhb_c, BHBtpp, HBRCH, ACSPHAC40, PHADPC40
# Genes Associated: PP_4549, PP_4550, PP_4762, PP_5004, PP_3073, PP_3074, PP_0763
#
# bhb_e
# -1
# C4H7O3
# (R)-3-Hydroxybutanoate
# e
# {'sbo': 'SBO:0000247', 'bigg.metabolite': 'bhb', 'biocyc': 'META:CPD-335', 'chebi': ['CHEBI:18666', 'CHEBI:10983', 'CHEBI:17066', 'CHEBI:322'], 'hmdb': 'HMDB00011', 'inchi_key': 'WHBMMWSBFZVSSR-GSVOUGTGSA-M', 'kegg.compound': 'C01089', 'lipidmaps': 'LMFA01050243', 'metanetx.chemical': 'MNXM663', 'reactome.compound': ['73911', '5696461'], 'sabiork': '2245', 'seed.compound': 'cpd00797'}
# Related Reactions: RHA40tex, EX_bhb_e
# Genes Associated:
#
# bhb_p
# -1
# C4H7O3
# (R)-3-Hydroxybutanoate
# p
# {'sbo': 'SBO:0000247', 'bigg.metabolite': 'bhb', 'biocyc': 'META:CPD-335', 'chebi': ['CHEBI:18666', 'CHEBI:10983', 'CHEBI:17066', 'CHEBI:322'], 'hmdb': 'HMDB00011', 'inchi_key': 'WHBMMWSBFZVSSR-GSVOUGTGSA-M', 'kegg.compound': 'C01089', 'lipidmaps': 'LMFA01050243', 'metanetx.chemical': 'MNXM663', 'reactome.compound': ['73911', '5696461'], 'sabiork': '2245', 'seed.compound': 'cpd00797'}
# Related Reactions: RHA40tex, RHA40tpp, BHBtpp
# Genes Associated: PP_3074

# %%
# Base directory path
base_dir = Path.home() / "Documents" / "PhD" / "10-19 Research" / "11 Data" / "11.09_Models"
# Correct path construction using '/' operator
file_path = base_dir /"250709_iJN1463_updated_5.sbml"
sbml_filename = file_path

#json_filename = file_path

#cobra.io.json.save_json_model(model,json_filename)
cobra.io.write_sbml_model(model, sbml_filename)

# %% [markdown]
# # calculating the yield for different ratio

# %% [markdown]
# change the formula of terephtalic acid

# %%
metabolite_id = 'terepa_c'
metabolite = model.metabolites.get_by_id(metabolite_id)
initial_formula = metabolite.formula
metabolite.formula = 'C8H6O4'

metabolite_id = 'terepa_c'
if metabolite_id in model.metabolites:
    metabolite = model.metabolites.get_by_id(metabolite_id)
    metabolite.charge = -0
    metabolite.compartment = 'c'
    
    print(list(metabolite.reactions))
# Out:
# [<Reaction SK_terepa_c at 0x19152427090>, <Reaction TEREDEOXY at 0x1915241e350>]

# %% [markdown]
# create the polymers metabolite in the model

# %%
from cobra import Model, Reaction, Metabolite, Gene
new_metabolite = Metabolite(
    id='PET_c',     # Metabolite ID
    name='PET',     # Metabolite Name
    formula='C10H8O4',         # Chemical Formula
    compartment='c'            # Compartment (e.g., cytoplasm)
)
new_metabolite.charge = -0

model.add_metabolites([new_metabolite])

new_metabolite1 = Metabolite(
    id='PU_c',     # Metabolite ID
    name='PU',     # Metabolite Name
    formula='C18H28O8',         # Chemical Formula
    compartment='c'            # Compartment (e.g., cytoplasm)
)
new_metabolite1.charge = -0

model.add_metabolites([new_metabolite1])


new_metabolite2 = Metabolite(
    id='PBAT_c',     # Metabolite ID
    name='PBAT',     # Metabolite Name
    formula='C18H26O10',         # Chemical Formula
    compartment='c'            # Compartment (e.g., cytoplasm)
)
new_metabolite2.charge = -0

model.add_metabolites([new_metabolite2])

# %% [markdown]
# Create the polymers reaction

# %%
from cobra import Model, Reaction, Metabolite, Gene

reaction = Reaction('PET_mix_uptake')
reaction.name = 'PET mixture uptake'
reaction.lower_bound =  0.0
reaction.upper_bound = 1000.0
etheglycol = model.metabolites.get_by_id('etheglycol_c')
terepa = model.metabolites.get_by_id('terepa_c')
pet = model.metabolites.get_by_id('PET_c')
h2o = model.metabolites.get_by_id('h2o_c')
reaction.add_metabolites({etheglycol:-1.,terepa:-1.,pet:1.,h2o:2.})
model.add_reactions([reaction])

reaction1 = Reaction('PU_mix_uptake')
reaction1.name = 'PU mixture uptake'
reaction1.lower_bound =  0.0
reaction1.upper_bound = 1000.0
etheglycol = model.metabolites.get_by_id('etheglycol_c')
adpac = model.metabolites.get_by_id('adpac_c')
btdl = model.metabolites.get_by_id('14btdl_c')
pu = model.metabolites.get_by_id('PU_c')
h2o = model.metabolites.get_by_id('h2o_c')
reaction1.add_metabolites({etheglycol:-1.0,adpac:-2.,btdl:-1.,pu:1.,h2o:4.})
model.add_reactions([reaction1])

reaction2 = Reaction('PBAT_mix_uptake')
reaction2.name = 'PBAT mixture uptake'
reaction2.lower_bound =  0.0
reaction2.upper_bound = 1000.0
terepa = model.metabolites.get_by_id('terepa_c')
adpac = model.metabolites.get_by_id('adpac_c')
btdl = model.metabolites.get_by_id('14btdl_c')
pbat = model.metabolites.get_by_id('PBAT_c')
h2o = model.metabolites.get_by_id('h2o_c')
reaction2.add_metabolites({terepa:-0.88,adpac:-1.112,btdl:-2.,pbat:1.})
model.add_reactions([reaction2])

# %% [markdown]
# Ratio variation

# %%
import numpy as np

# polymer composition dictionaries
mixture_PU = {
    'SK_etheglycol_c': 0.25,
    'SK_terepa_c': 0.0,
    'SK_adpac_c': 0.5,
    'SK_14btdl_c': 0.25
}

mixture_PET = {
    'SK_etheglycol_c': 0.5,
    'SK_terepa_c': 0.5,
    'SK_adpac_c': 0.0,
    'SK_14btdl_c': 0.0
}

mixture_PBAT = {
    'SK_etheglycol_c': 0.0,
    'SK_terepa_c': 0.222,
    'SK_adpac_c': 0.278,
    'SK_14btdl_c': 0.5
}

substrate_carbons = {
    'SK_etheglycol_c': 2,
    'SK_terepa_c': 8,
    'SK_adpac_c': 6,
    'SK_14btdl_c': 4
}

polymers = {
    "PET": mixture_PET,
    "PU": mixture_PU,
    "PBAT": mixture_PBAT
}

total_uptake = 10.0  # mmol/gDW/h
# results storage
rows = []

# --------- LOOP OVER 3 BATCHES ---------
for fixed_polymer in ["PET", "PU", "PBAT"]:
    print(f"\n--- Batch with {fixed_polymer} fixed at 0.33 ---")

    for i in np.arange(0.0, 0.5, 0.01):  # the remaining 0.667 split between other 2
        # reset flux tracking
        total_sub_cflux = 0.0

        # assign fractions
        fractions = {"PET": 0.0, "PU": 0.0, "PBAT": 0.0}
        fractions[fixed_polymer] = 0.5

        others = [p for p in polymers.keys() if p != fixed_polymer]
        fractions[others[0]] = i
        fractions[others[1]] = 0.5 - i

        # ----  SUM TOTAL UPTAKE PER MET ----
        uptake_dict = {met: 0.0 for met in substrate_carbons}
        for polymer, mixture in polymers.items():
            for met, coeff in mixture.items():
                uptake_dict[met] += total_uptake * fractions[polymer] * coeff

        # apply once per metabolite
        for met, lb_value in uptake_dict.items():
            rxn = model.reactions.get_by_id(met)
            rxn.bounds = (-lb_value, 0.0)

        print(f"Fractions → PET={fractions['PET']}, PU={fractions['PU']}, PBAT={fractions['PBAT']}")

        # optimize model
        model.objective = "SK_bhb_c"
        sol = model.optimize()

        # carbon balance
        for rxn_id in substrate_carbons:
            upt = -model.reactions.get_by_id(rxn_id).flux
            print(f'{rxn_id} flux = {upt}')
            total_sub_cflux += upt * substrate_carbons[rxn_id]

        prod_flux = sol.fluxes["SK_bhb_c"]
        prod_cflux = prod_flux * 4  # BHB has 4 carbons
        carbon_yield = prod_cflux / total_sub_cflux if total_sub_cflux > 0 else None

        print(f"Carbon yield = {carbon_yield}")

        
        rows.append({
            "fixed_polymer": fixed_polymer,
            "var_frac": i,
            "frac_PET": fractions["PET"],
            "frac_PU": fractions["PU"],
            "frac_PBAT": fractions["PBAT"],
            "carbon_yield": carbon_yield,
            "prod_flux": prod_flux,
        })

# convert to DataFrame
df_ratios_third = pd.DataFrame(rows)
# save to CSV if you like:
df_ratios_third.to_excel("250924_polymer_mixture_yield_sweep_half.xlsx", index=False)
# Out:
# --- Batch with PET fixed at 0.33 ---
# Fractions → PET=0.5, PU=0.0, PBAT=0.5
# SK_etheglycol_c flux = 2.5
# SK_terepa_c flux = 3.6100000000000003
# SK_adpac_c flux = 1.3900000000000001
# SK_14btdl_c flux = 2.5
# Carbon yield = 0.5266181539639989
# Fractions → PET=0.5, PU=0.01, PBAT=0.49
# SK_etheglycol_c flux = 2.525
# SK_terepa_c flux = 3.5878
# SK_adpac_c flux = 1.4122000000000003
# SK_14btdl_c flux = 2.475
# Carbon yield = 0.5270922540939578
# Fractions → PET=0.5, PU=0.02, PBAT=0.48
# SK_etheglycol_c flux = 2.55
# SK_terepa_c flux = 3.5656
# SK_adpac_c flux = 1.4344000000000001
# SK_14btdl_c flux = 2.4499999999999997
# Carbon yield = 0.5275680745398922
# Fractions → PET=0.5, PU=0.03, PBAT=0.47
# SK_etheglycol_c flux = 2.575
# SK_terepa_c flux = 3.5434
# SK_adpac_c flux = 1.4566
# SK_14btdl_c flux = 2.425
# Carbon yield = 0.5280456246823071
# Fractions → PET=0.5, PU=0.04, PBAT=0.46
# SK_etheglycol_c flux = 2.6
# SK_terepa_c flux = 3.5212000000000003
# SK_adpac_c flux = 1.4788000000000001
# SK_14btdl_c flux = 2.4000000000000004
# Carbon yield = 0.5285249139700325
# Fractions → PET=0.5, PU=0.05, PBAT=0.45
# SK_etheglycol_c flux = 2.625
# SK_terepa_c flux = 3.499
# SK_adpac_c flux = 1.5010000000000001
# SK_14btdl_c flux = 2.375
# Carbon yield = 0.5290059519208477
# Fractions → PET=0.5, PU=0.06, PBAT=0.44
# SK_etheglycol_c flux = 2.65
# SK_terepa_c flux = 3.4768
# SK_adpac_c flux = 1.5232000000000003
# SK_14btdl_c flux = 2.35
# Carbon yield = 0.5294887481221066
# Fractions → PET=0.5, PU=0.07, PBAT=0.43
# SK_etheglycol_c flux = 2.675
# SK_terepa_c flux = 3.4546
# SK_adpac_c flux = 1.5454
# SK_14btdl_c flux = 2.3249999999999997
# Carbon yield = 0.529973312231377
# Fractions → PET=0.5, PU=0.08, PBAT=0.42
# SK_etheglycol_c flux = 2.7
# SK_terepa_c flux = 3.4324
# SK_adpac_c flux = 1.5676
# SK_14btdl_c flux = 2.3000000000000003
# Carbon yield = 0.5304596539770876
# Fractions → PET=0.5, PU=0.09, PBAT=0.41000000000000003
# SK_etheglycol_c flux = 2.725
# SK_terepa_c flux = 3.4102
# SK_adpac_c flux = 1.5898
# SK_14btdl_c flux = 2.2750000000000004
# Carbon yield = 0.5309477831591732
# Fractions → PET=0.5, PU=0.1, PBAT=0.4
# SK_etheglycol_c flux = 2.75
# SK_terepa_c flux = 3.388
# SK_adpac_c flux = 1.612
# SK_14btdl_c flux = 2.25
# Carbon yield = 0.5314377096497391
# Fractions → PET=0.5, PU=0.11, PBAT=0.39
# SK_etheglycol_c flux = 2.775
# SK_terepa_c flux = 3.3658
# SK_adpac_c flux = 1.6342000000000003
# SK_14btdl_c flux = 2.225
# Carbon yield = 0.5319294433937203
# Fractions → PET=0.5, PU=0.12, PBAT=0.38
# SK_etheglycol_c flux = 2.8
# SK_terepa_c flux = 3.3436
# SK_adpac_c flux = 1.6564
# SK_14btdl_c flux = 2.1999999999999997
# Carbon yield = 0.5324229944095584
# Fractions → PET=0.5, PU=0.13, PBAT=0.37
# SK_etheglycol_c flux = 2.825
# SK_terepa_c flux = 3.3214
# SK_adpac_c flux = 1.6786000000000003
# SK_14btdl_c flux = 2.1750000000000003
# Carbon yield = 0.5329183727898847
# Fractions → PET=0.5, PU=0.14, PBAT=0.36
# SK_etheglycol_c flux = 2.85
# SK_terepa_c flux = 3.2992
# SK_adpac_c flux = 1.7008
# SK_14btdl_c flux = 2.15
# Carbon yield = 0.5334155887021991
# Fractions → PET=0.5, PU=0.15, PBAT=0.35
# SK_etheglycol_c flux = 2.875
# SK_terepa_c flux = 3.277
# SK_adpac_c flux = 1.723
# SK_14btdl_c flux = 2.125
# Carbon yield = 0.5339146523895762
# Fractions → PET=0.5, PU=0.16, PBAT=0.33999999999999997
# SK_etheglycol_c flux = 2.9
# SK_terepa_c flux = 3.2548
# SK_adpac_c flux = 1.7452
# SK_14btdl_c flux = 2.0999999999999996
# Carbon yield = 0.5344155741713614
# Fractions → PET=0.5, PU=0.17, PBAT=0.32999999999999996
# SK_etheglycol_c flux = 2.925
# SK_terepa_c flux = 3.2325999999999997
# SK_adpac_c flux = 1.7674
# SK_14btdl_c flux = 2.075
# Carbon yield = 0.534918364443883
# Fractions → PET=0.5, PU=0.18, PBAT=0.32
# SK_etheglycol_c flux = 2.95
# SK_terepa_c flux = 3.2104
# SK_adpac_c flux = 1.7896
# SK_14btdl_c flux = 2.05
# Carbon yield = 0.5354230336811774
# Fractions → PET=0.5, PU=0.19, PBAT=0.31
# SK_etheglycol_c flux = 2.975
# SK_terepa_c flux = 3.1882
# SK_adpac_c flux = 1.8118
# SK_14btdl_c flux = 2.025
# Carbon yield = 0.5359295924357095
# Fractions → PET=0.5, PU=0.2, PBAT=0.3
# SK_etheglycol_c flux = 3.0
# SK_terepa_c flux = 3.166
# SK_adpac_c flux = 1.834
# SK_14btdl_c flux = 2.0
# Carbon yield = 0.5364380513391088
# Fractions → PET=0.5, PU=0.21, PBAT=0.29000000000000004
# SK_etheglycol_c flux = 3.025
# SK_terepa_c flux = 3.1438
# SK_adpac_c flux = 1.8562000000000003
# SK_14btdl_c flux = 1.975
# Carbon yield = 0.5369484211029197
# Fractions → PET=0.5, PU=0.22, PBAT=0.28
# SK_etheglycol_c flux = 3.05
# SK_terepa_c flux = 3.1216
# SK_adpac_c flux = 1.8784
# SK_14btdl_c flux = 1.9500000000000002
# Carbon yield = 0.5374607125193446
# Fractions → PET=0.5, PU=0.23, PBAT=0.27
# SK_etheglycol_c flux = 3.075
# SK_terepa_c flux = 3.0994
# SK_adpac_c flux = 1.9006000000000003
# SK_14btdl_c flux = 1.9250000000000003
# Carbon yield = 0.537974936462013
# Fractions → PET=0.5, PU=0.24, PBAT=0.26
# SK_etheglycol_c flux = 3.1
# SK_terepa_c flux = 3.0772
# SK_adpac_c flux = 1.9228
# SK_14btdl_c flux = 1.9
# Carbon yield = 0.5384911038867454
# Fractions → PET=0.5, PU=0.25, PBAT=0.25
# SK_etheglycol_c flux = 3.125
# SK_terepa_c flux = 3.055
# SK_adpac_c flux = 1.945
# SK_14btdl_c flux = 1.875
# Carbon yield = 0.5390092258323311
# Fractions → PET=0.5, PU=0.26, PBAT=0.24
# SK_etheglycol_c flux = 3.15
# SK_terepa_c flux = 3.0328
# SK_adpac_c flux = 1.9672
# SK_14btdl_c flux = 1.85
# Carbon yield = 0.5395293134213197
# Fractions → PET=0.5, PU=0.27, PBAT=0.22999999999999998
# SK_etheglycol_c flux = 3.175
# SK_terepa_c flux = 3.0106
# SK_adpac_c flux = 1.9894
# SK_14btdl_c flux = 1.825
# Carbon yield = 0.5400513778608134
# Fractions → PET=0.5, PU=0.28, PBAT=0.21999999999999997
# SK_etheglycol_c flux = 3.2
# SK_terepa_c flux = 2.9884
# SK_adpac_c flux = 2.0116
# SK_14btdl_c flux = 1.7999999999999998
# Carbon yield = 0.5405754304432725
# Fractions → PET=0.5, PU=0.29, PBAT=0.21000000000000002
# SK_etheglycol_c flux = 3.225
# SK_terepa_c flux = 2.9662
# SK_adpac_c flux = 2.0338000000000003
# SK_14btdl_c flux = 1.775
# Carbon yield = 0.5411014825473304
# Fractions → PET=0.5, PU=0.3, PBAT=0.2
# SK_etheglycol_c flux = 3.25
# SK_terepa_c flux = 2.944
# SK_adpac_c flux = 2.056
# SK_14btdl_c flux = 1.75
# Carbon yield = 0.5416295456386171
# Fractions → PET=0.5, PU=0.31, PBAT=0.19
# SK_etheglycol_c flux = 3.275
# SK_terepa_c flux = 2.9218
# SK_adpac_c flux = 2.0782
# SK_14btdl_c flux = 1.725
# Carbon yield = 0.5421596312705919
# Fractions → PET=0.5, PU=0.32, PBAT=0.18
# SK_etheglycol_c flux = 3.3
# SK_terepa_c flux = 2.8996
# SK_adpac_c flux = 2.1004
# SK_14btdl_c flux = 1.7
# Carbon yield = 0.5426917510853843
# Fractions → PET=0.5, PU=0.33, PBAT=0.16999999999999998
# SK_etheglycol_c flux = 3.325
# SK_terepa_c flux = 2.8773999999999997
# SK_adpac_c flux = 2.1226000000000003
# SK_14btdl_c flux = 1.6749999999999998
# Carbon yield = 0.5432259168146504
# Fractions → PET=0.5, PU=0.34, PBAT=0.15999999999999998
# SK_etheglycol_c flux = 3.35
# SK_terepa_c flux = 2.8552
# SK_adpac_c flux = 2.1448
# SK_14btdl_c flux = 1.65
# Carbon yield = 0.5437621402804302
# Fractions → PET=0.5, PU=0.35000000000000003, PBAT=0.14999999999999997
# SK_etheglycol_c flux = 3.375
# SK_terepa_c flux = 2.8329999999999997
# SK_adpac_c flux = 2.1670000000000003
# SK_14btdl_c flux = 1.625
# Carbon yield = 0.5443004333960262
# Fractions → PET=0.5, PU=0.36, PBAT=0.14
# SK_etheglycol_c flux = 3.4
# SK_terepa_c flux = 2.8108
# SK_adpac_c flux = 2.1892
# SK_14btdl_c flux = 1.6
# Carbon yield = 0.5448408081668772
# Fractions → PET=0.5, PU=0.37, PBAT=0.13
# SK_etheglycol_c flux = 3.425
# SK_terepa_c flux = 2.7886
# SK_adpac_c flux = 2.2114000000000003
# SK_14btdl_c flux = 1.5750000000000002
# Carbon yield = 0.5453832766914586
# Fractions → PET=0.5, PU=0.38, PBAT=0.12
# SK_etheglycol_c flux = 3.45
# SK_terepa_c flux = 2.7664
# SK_adpac_c flux = 2.2336
# SK_14btdl_c flux = 1.5499999999999998
# Carbon yield = 0.5459278511621793
# Fractions → PET=0.5, PU=0.39, PBAT=0.10999999999999999
# SK_etheglycol_c flux = 3.475
# SK_terepa_c flux = 2.7442
# SK_adpac_c flux = 2.2558000000000002
# SK_14btdl_c flux = 1.525
# Carbon yield = 0.5464745438662998
# Fractions → PET=0.5, PU=0.4, PBAT=0.09999999999999998
# SK_etheglycol_c flux = 3.5
# SK_terepa_c flux = 2.722
# SK_adpac_c flux = 2.278
# SK_14btdl_c flux = 1.5
# Carbon yield = 0.5470233671868548
# Fractions → PET=0.5, PU=0.41000000000000003, PBAT=0.08999999999999997
# SK_etheglycol_c flux = 3.5250000000000004
# SK_terepa_c flux = 2.6997999999999998
# SK_adpac_c flux = 2.3002000000000002
# SK_14btdl_c flux = 1.475
# Carbon yield = 0.5475743336035878
# Fractions → PET=0.5, PU=0.42, PBAT=0.08000000000000002
# SK_etheglycol_c flux = 3.55
# SK_terepa_c flux = 2.6776
# SK_adpac_c flux = 2.3224
# SK_14btdl_c flux = 1.4500000000000002
# Carbon yield = 0.5481274556938942
# Fractions → PET=0.5, PU=0.43, PBAT=0.07
# SK_etheglycol_c flux = 3.575
# SK_terepa_c flux = 2.6554
# SK_adpac_c flux = 2.3446
# SK_14btdl_c flux = 1.425
# Carbon yield = 0.5486827461337858
# Fractions → PET=0.5, PU=0.44, PBAT=0.06
# SK_etheglycol_c flux = 3.6
# SK_terepa_c flux = 2.6332
# SK_adpac_c flux = 2.3668
# SK_14btdl_c flux = 1.4000000000000001
# Carbon yield = 0.5492402176988503
# Fractions → PET=0.5, PU=0.45, PBAT=0.04999999999999999
# SK_etheglycol_c flux = 3.625
# SK_terepa_c flux = 2.6109999999999998
# SK_adpac_c flux = 2.389
# SK_14btdl_c flux = 1.375
# Carbon yield = 0.5497998832652388
# Fractions → PET=0.5, PU=0.46, PBAT=0.03999999999999998
# SK_etheglycol_c flux = 3.6500000000000004
# SK_terepa_c flux = 2.5888
# SK_adpac_c flux = 2.4112
# SK_14btdl_c flux = 1.35
# Carbon yield = 0.550361755810651
# Fractions → PET=0.5, PU=0.47000000000000003, PBAT=0.02999999999999997
# SK_etheglycol_c flux = 3.675
# SK_terepa_c flux = 2.5665999999999998
# SK_adpac_c flux = 2.4334000000000002
# SK_14btdl_c flux = 1.325
# Carbon yield = 0.5509258484153433
# Fractions → PET=0.5, PU=0.48, PBAT=0.020000000000000018
# SK_etheglycol_c flux = 3.7
# SK_terepa_c flux = 2.5444
# SK_adpac_c flux = 2.4556
# SK_14btdl_c flux = 1.3
# Carbon yield = 0.5514921742631399
# Fractions → PET=0.5, PU=0.49, PBAT=0.010000000000000009
# SK_etheglycol_c flux = 3.725
# SK_terepa_c flux = 2.5222
# SK_adpac_c flux = 2.4778000000000002
# SK_14btdl_c flux = 1.2750000000000001
# Carbon yield = 0.5520607466424623
#
# --- Batch with PU fixed at 0.33 ---
# Fractions → PET=0.0, PU=0.5, PBAT=0.5
# SK_etheglycol_c flux = 1.25
# SK_terepa_c flux = 1.11
# SK_adpac_c flux = 3.89
# SK_14btdl_c flux = 3.75
# Carbon yield = 0.578238133547869
# Fractions → PET=0.01, PU=0.5, PBAT=0.49
# SK_etheglycol_c flux = 1.3
# SK_terepa_c flux = 1.1378000000000001
# SK_adpac_c flux = 3.8622000000000005
# SK_14btdl_c flux = 3.7
# Carbon yield = 0.5777484318256857
# Fractions → PET=0.02, PU=0.5, PBAT=0.48
# SK_etheglycol_c flux = 1.35
# SK_terepa_c flux = 1.1656
# SK_adpac_c flux = 3.8344
# SK_14btdl_c flux = 3.65
# Carbon yield = 0.5772578539305907
# Fractions → PET=0.03, PU=0.5, PBAT=0.47
# SK_etheglycol_c flux = 1.4
# SK_terepa_c flux = 1.1933999999999998
# SK_adpac_c flux = 3.8066
# SK_14btdl_c flux = 3.5999999999999996
# Carbon yield = 0.5767663975090144
# Fractions → PET=0.04, PU=0.5, PBAT=0.46
# SK_etheglycol_c flux = 1.45
# SK_terepa_c flux = 1.2212
# SK_adpac_c flux = 3.7788000000000004
# SK_14btdl_c flux = 3.5500000000000003
# Carbon yield = 0.576274060198941
# Fractions → PET=0.05, PU=0.5, PBAT=0.45
# SK_etheglycol_c flux = 1.5
# SK_terepa_c flux = 1.249
# SK_adpac_c flux = 3.7510000000000003
# SK_14btdl_c flux = 3.5
# Carbon yield = 0.5757808396298844
# Fractions → PET=0.06, PU=0.5, PBAT=0.44
# SK_etheglycol_c flux = 1.55
# SK_terepa_c flux = 1.2768000000000002
# SK_adpac_c flux = 3.7232000000000003
# SK_14btdl_c flux = 3.45
# Carbon yield = 0.5752867334228442
# Fractions → PET=0.07, PU=0.5, PBAT=0.43
# SK_etheglycol_c flux = 1.6
# SK_terepa_c flux = 1.3046
# SK_adpac_c flux = 3.6954000000000002
# SK_14btdl_c flux = 3.4
# Carbon yield = 0.5747917391902737
# Fractions → PET=0.08, PU=0.5, PBAT=0.42
# SK_etheglycol_c flux = 1.65
# SK_terepa_c flux = 1.3324
# SK_adpac_c flux = 3.6676
# SK_14btdl_c flux = 3.35
# Carbon yield = 0.5742958545360279
# Fractions → PET=0.09, PU=0.5, PBAT=0.41000000000000003
# SK_etheglycol_c flux = 1.7
# SK_terepa_c flux = 1.3602
# SK_adpac_c flux = 3.6398
# SK_14btdl_c flux = 3.3000000000000003
# Carbon yield = 0.5737990770553364
# Fractions → PET=0.1, PU=0.5, PBAT=0.4
# SK_etheglycol_c flux = 1.75
# SK_terepa_c flux = 1.388
# SK_adpac_c flux = 3.612
# SK_14btdl_c flux = 3.25
# Carbon yield = 0.5733014043347685
# Fractions → PET=0.11, PU=0.5, PBAT=0.39
# SK_etheglycol_c flux = 1.8
# SK_terepa_c flux = 1.4158000000000002
# SK_adpac_c flux = 3.5842
# SK_14btdl_c flux = 3.2
# Carbon yield = 0.5728028339521778
# Fractions → PET=0.12, PU=0.5, PBAT=0.38
# SK_etheglycol_c flux = 1.85
# SK_terepa_c flux = 1.4436
# SK_adpac_c flux = 3.5564
# SK_14btdl_c flux = 3.15
# Carbon yield = 0.572303363476677
# Fractions → PET=0.13, PU=0.5, PBAT=0.37
# SK_etheglycol_c flux = 1.9
# SK_terepa_c flux = 1.4714
# SK_adpac_c flux = 3.5286
# SK_14btdl_c flux = 3.1
# Carbon yield = 0.5718029904685941
# Fractions → PET=0.14, PU=0.5, PBAT=0.36
# SK_etheglycol_c flux = 1.9500000000000002
# SK_terepa_c flux = 1.4992
# SK_adpac_c flux = 3.5008
# SK_14btdl_c flux = 3.05
# Carbon yield = 0.5713017124794284
# Fractions → PET=0.15, PU=0.5, PBAT=0.35
# SK_etheglycol_c flux = 2.0
# SK_terepa_c flux = 1.5270000000000001
# SK_adpac_c flux = 3.473
# SK_14btdl_c flux = 3.0
# Carbon yield = 0.5707995270518212
# Fractions → PET=0.16, PU=0.5, PBAT=0.33999999999999997
# SK_etheglycol_c flux = 2.05
# SK_terepa_c flux = 1.5548
# SK_adpac_c flux = 3.4452
# SK_14btdl_c flux = 2.9499999999999997
# Carbon yield = 0.5702964317195004
# Fractions → PET=0.17, PU=0.5, PBAT=0.32999999999999996
# SK_etheglycol_c flux = 2.1
# SK_terepa_c flux = 1.5826
# SK_adpac_c flux = 3.4173999999999998
# SK_14btdl_c flux = 2.9
# Carbon yield = 0.5697924240072539
# Fractions → PET=0.18, PU=0.5, PBAT=0.32
# SK_etheglycol_c flux = 2.15
# SK_terepa_c flux = 1.6103999999999998
# SK_adpac_c flux = 3.3896
# SK_14btdl_c flux = 2.85
# Carbon yield = 0.5692875014308854
# Fractions → PET=0.19, PU=0.5, PBAT=0.31
# SK_etheglycol_c flux = 2.2
# SK_terepa_c flux = 1.6381999999999999
# SK_adpac_c flux = 3.3618
# SK_14btdl_c flux = 2.8
# Carbon yield = 0.5687816614971642
# Fractions → PET=0.2, PU=0.5, PBAT=0.3
# SK_etheglycol_c flux = 2.25
# SK_terepa_c flux = 1.666
# SK_adpac_c flux = 3.334
# SK_14btdl_c flux = 2.75
# Carbon yield = 0.5682749017038008
# Fractions → PET=0.21, PU=0.5, PBAT=0.29000000000000004
# SK_etheglycol_c flux = 2.3
# SK_terepa_c flux = 1.6938
# SK_adpac_c flux = 3.3062
# SK_14btdl_c flux = 2.7
# Carbon yield = 0.5677672195393911
# Fractions → PET=0.22, PU=0.5, PBAT=0.28
# SK_etheglycol_c flux = 2.35
# SK_terepa_c flux = 1.7216
# SK_adpac_c flux = 3.2784
# SK_14btdl_c flux = 2.6500000000000004
# Carbon yield = 0.567258612483382
# Fractions → PET=0.23, PU=0.5, PBAT=0.27
# SK_etheglycol_c flux = 2.4000000000000004
# SK_terepa_c flux = 1.7494
# SK_adpac_c flux = 3.2506000000000004
# SK_14btdl_c flux = 2.6
# Carbon yield = 0.5667490780060291
# Fractions → PET=0.24, PU=0.5, PBAT=0.26
# SK_etheglycol_c flux = 2.45
# SK_terepa_c flux = 1.7772000000000001
# SK_adpac_c flux = 3.2228000000000003
# SK_14btdl_c flux = 2.55
# Carbon yield = 0.5662386135683515
# Fractions → PET=0.25, PU=0.5, PBAT=0.25
# SK_etheglycol_c flux = 2.5
# SK_terepa_c flux = 1.8050000000000002
# SK_adpac_c flux = 3.1950000000000003
# SK_14btdl_c flux = 2.5
# Carbon yield = 0.5657272166220939
# Fractions → PET=0.26, PU=0.5, PBAT=0.24
# SK_etheglycol_c flux = 2.55
# SK_terepa_c flux = 1.8328
# SK_adpac_c flux = 3.1672000000000002
# SK_14btdl_c flux = 2.45
# Carbon yield = 0.5652148846096827
# Fractions → PET=0.27, PU=0.5, PBAT=0.22999999999999998
# SK_etheglycol_c flux = 2.6
# SK_terepa_c flux = 1.8606
# SK_adpac_c flux = 3.1394
# SK_14btdl_c flux = 2.4
# Carbon yield = 0.564701614964181
# Fractions → PET=0.28, PU=0.5, PBAT=0.21999999999999997
# SK_etheglycol_c flux = 2.6500000000000004
# SK_terepa_c flux = 1.8884
# SK_adpac_c flux = 3.1116
# SK_14btdl_c flux = 2.3499999999999996
# Carbon yield = 0.5641874051092486
# Fractions → PET=0.29, PU=0.5, PBAT=0.21000000000000002
# SK_etheglycol_c flux = 2.7
# SK_terepa_c flux = 1.9162
# SK_adpac_c flux = 3.0838
# SK_14btdl_c flux = 2.3
# Carbon yield = 0.563672252459098
# Fractions → PET=0.3, PU=0.5, PBAT=0.2
# SK_etheglycol_c flux = 2.75
# SK_terepa_c flux = 1.944
# SK_adpac_c flux = 3.056
# SK_14btdl_c flux = 2.25
# Carbon yield = 0.5631561544184513
# Fractions → PET=0.31, PU=0.5, PBAT=0.19
# SK_etheglycol_c flux = 2.8
# SK_terepa_c flux = 1.9718
# SK_adpac_c flux = 3.0282
# SK_14btdl_c flux = 2.2
# Carbon yield = 0.5626391083824954
# Fractions → PET=0.32, PU=0.5, PBAT=0.18
# SK_etheglycol_c flux = 2.85
# SK_terepa_c flux = 1.9996
# SK_adpac_c flux = 3.0004
# SK_14btdl_c flux = 2.15
# Carbon yield = 0.5621211117368402
# Fractions → PET=0.33, PU=0.5, PBAT=0.16999999999999998
# SK_etheglycol_c flux = 2.9000000000000004
# SK_terepa_c flux = 2.0274
# SK_adpac_c flux = 2.9726
# SK_14btdl_c flux = 2.0999999999999996
# Carbon yield = 0.5616021618574734
# Fractions → PET=0.34, PU=0.5, PBAT=0.15999999999999998
# SK_etheglycol_c flux = 2.95
# SK_terepa_c flux = 2.0552
# SK_adpac_c flux = 2.9448
# SK_14btdl_c flux = 2.05
# Carbon yield = 0.5610822561107148
# Fractions → PET=0.35000000000000003, PU=0.5, PBAT=0.14999999999999997
# SK_etheglycol_c flux = 3.0
# SK_terepa_c flux = 2.083
# SK_adpac_c flux = 2.917
# SK_14btdl_c flux = 1.9999999999999998
# Carbon yield = 0.5605613918531747
# Fractions → PET=0.36, PU=0.5, PBAT=0.14
# SK_etheglycol_c flux = 3.05
# SK_terepa_c flux = 2.1108
# SK_adpac_c flux = 2.8892
# SK_14btdl_c flux = 1.9500000000000002
# Carbon yield = 0.5600395664317068
# Fractions → PET=0.37, PU=0.5, PBAT=0.13
# SK_etheglycol_c flux = 3.1
# SK_terepa_c flux = 2.1386000000000003
# SK_adpac_c flux = 2.8614
# SK_14btdl_c flux = 1.9
# Carbon yield = 0.5595167771833637
# Fractions → PET=0.38, PU=0.5, PBAT=0.12
# SK_etheglycol_c flux = 3.15
# SK_terepa_c flux = 2.1664
# SK_adpac_c flux = 2.8336
# SK_14btdl_c flux = 1.85
# Carbon yield = 0.5589930214353525
# Fractions → PET=0.39, PU=0.5, PBAT=0.10999999999999999
# SK_etheglycol_c flux = 3.2
# SK_terepa_c flux = 2.1942000000000004
# SK_adpac_c flux = 2.8058
# SK_14btdl_c flux = 1.7999999999999998
# Carbon yield = 0.5584682965049889
# Fractions → PET=0.4, PU=0.5, PBAT=0.09999999999999998
# SK_etheglycol_c flux = 3.25
# SK_terepa_c flux = 2.222
# SK_adpac_c flux = 2.778
# SK_14btdl_c flux = 1.75
# Carbon yield = 0.5579425996996497
# Fractions → PET=0.41000000000000003, PU=0.5, PBAT=0.08999999999999997
# SK_etheglycol_c flux = 3.3000000000000003
# SK_terepa_c flux = 2.2498
# SK_adpac_c flux = 2.7502
# SK_14btdl_c flux = 1.6999999999999997
# Carbon yield = 0.5574159283167321
# Fractions → PET=0.42, PU=0.5, PBAT=0.08000000000000002
# SK_etheglycol_c flux = 3.35
# SK_terepa_c flux = 2.2776
# SK_adpac_c flux = 2.7224
# SK_14btdl_c flux = 1.6500000000000001
# Carbon yield = 0.5568882796435913
# Fractions → PET=0.43, PU=0.5, PBAT=0.07
# SK_etheglycol_c flux = 3.4
# SK_terepa_c flux = 2.3054
# SK_adpac_c flux = 2.6946
# SK_14btdl_c flux = 1.6
# Carbon yield = 0.5563596509575242
# Fractions → PET=0.44, PU=0.5, PBAT=0.06
# SK_etheglycol_c flux = 3.45
# SK_terepa_c flux = 2.3332
# SK_adpac_c flux = 2.6668
# SK_14btdl_c flux = 1.55
# Carbon yield = 0.5558300395256917
# Fractions → PET=0.45, PU=0.5, PBAT=0.04999999999999999
# SK_etheglycol_c flux = 3.5
# SK_terepa_c flux = 2.3609999999999998
# SK_adpac_c flux = 2.639
# SK_14btdl_c flux = 1.5
# Carbon yield = 0.5552994426050878
# Fractions → PET=0.46, PU=0.5, PBAT=0.03999999999999998
# SK_etheglycol_c flux = 3.5500000000000003
# SK_terepa_c flux = 2.3888000000000003
# SK_adpac_c flux = 2.6111999999999997
# SK_14btdl_c flux = 1.45
# Carbon yield = 0.5547678574424889
# Fractions → PET=0.47000000000000003, PU=0.5, PBAT=0.02999999999999997
# SK_etheglycol_c flux = 3.6
# SK_terepa_c flux = 2.4166
# SK_adpac_c flux = 2.5834
# SK_14btdl_c flux = 1.4
# Carbon yield = 0.5542352812744052
# Fractions → PET=0.48, PU=0.5, PBAT=0.020000000000000018
# SK_etheglycol_c flux = 3.65
# SK_terepa_c flux = 2.4444
# SK_adpac_c flux = 2.5556
# SK_14btdl_c flux = 1.35
# Carbon yield = 0.5537017113270352
# Fractions → PET=0.49, PU=0.5, PBAT=0.010000000000000009
# SK_etheglycol_c flux = 3.7
# SK_terepa_c flux = 2.4722000000000004
# SK_adpac_c flux = 2.5278
# SK_14btdl_c flux = 1.3
# Carbon yield = 0.5531671448162138
#
# --- Batch with PBAT fixed at 0.33 ---
# Fractions → PET=0.0, PU=0.5, PBAT=0.5
# SK_etheglycol_c flux = 1.25
# SK_terepa_c flux = 1.11
# SK_adpac_c flux = 3.89
# SK_14btdl_c flux = 3.75
# Carbon yield = 0.5782381335478683
# Fractions → PET=0.01, PU=0.49, PBAT=0.5
# SK_etheglycol_c flux = 1.2750000000000001
# SK_terepa_c flux = 1.1600000000000001
# SK_adpac_c flux = 3.8400000000000003
# SK_14btdl_c flux = 3.725
# Carbon yield = 0.5771549125979514
# Fractions → PET=0.02, PU=0.48, PBAT=0.5
# SK_etheglycol_c flux = 1.3
# SK_terepa_c flux = 1.2100000000000002
# SK_adpac_c flux = 3.79
# SK_14btdl_c flux = 3.7
# Carbon yield = 0.5760738659173029
# Fractions → PET=0.03, PU=0.47, PBAT=0.5
# SK_etheglycol_c flux = 1.3249999999999997
# SK_terepa_c flux = 1.26
# SK_adpac_c flux = 3.7399999999999998
# SK_14btdl_c flux = 3.675
# Carbon yield = 0.5749949869661126
# Fractions → PET=0.04, PU=0.46, PBAT=0.5
# SK_etheglycol_c flux = 1.35
# SK_terepa_c flux = 1.31
# SK_adpac_c flux = 3.6900000000000004
# SK_14btdl_c flux = 3.6500000000000004
# Carbon yield = 0.5739182692307699
# Fractions → PET=0.05, PU=0.45, PBAT=0.5
# SK_etheglycol_c flux = 1.375
# SK_terepa_c flux = 1.36
# SK_adpac_c flux = 3.64
# SK_14btdl_c flux = 3.625
# Carbon yield = 0.572843706223735
# Fractions → PET=0.06, PU=0.44, PBAT=0.5
# SK_etheglycol_c flux = 1.4000000000000001
# SK_terepa_c flux = 1.4100000000000001
# SK_adpac_c flux = 3.5900000000000003
# SK_14btdl_c flux = 3.6
# Carbon yield = 0.5717712914834079
# Fractions → PET=0.07, PU=0.43, PBAT=0.5
# SK_etheglycol_c flux = 1.425
# SK_terepa_c flux = 1.4600000000000002
# SK_adpac_c flux = 3.54
# SK_14btdl_c flux = 3.575
# Carbon yield = 0.5707010185739971
# Fractions → PET=0.08, PU=0.42, PBAT=0.5
# SK_etheglycol_c flux = 1.4500000000000002
# SK_terepa_c flux = 1.5100000000000002
# SK_adpac_c flux = 3.49
# SK_14btdl_c flux = 3.55
# Carbon yield = 0.5696328810853958
# Fractions → PET=0.09, PU=0.41000000000000003, PBAT=0.5
# SK_etheglycol_c flux = 1.475
# SK_terepa_c flux = 1.56
# SK_adpac_c flux = 3.4400000000000004
# SK_14btdl_c flux = 3.5250000000000004
# Carbon yield = 0.5685668726330486
# Fractions → PET=0.1, PU=0.4, PBAT=0.5
# SK_etheglycol_c flux = 1.5
# SK_terepa_c flux = 1.61
# SK_adpac_c flux = 3.39
# SK_14btdl_c flux = 3.5
# Carbon yield = 0.5675029868578257
# Fractions → PET=0.11, PU=0.39, PBAT=0.5
# SK_etheglycol_c flux = 1.5250000000000001
# SK_terepa_c flux = 1.6600000000000001
# SK_adpac_c flux = 3.3400000000000003
# SK_14btdl_c flux = 3.475
# Carbon yield = 0.5664412174259009
# Fractions → PET=0.12, PU=0.38, PBAT=0.5
# SK_etheglycol_c flux = 1.5499999999999998
# SK_terepa_c flux = 1.71
# SK_adpac_c flux = 3.29
# SK_14btdl_c flux = 3.45
# Carbon yield = 0.5653815580286176
# Fractions → PET=0.13, PU=0.37, PBAT=0.5
# SK_etheglycol_c flux = 1.5750000000000002
# SK_terepa_c flux = 1.7600000000000002
# SK_adpac_c flux = 3.24
# SK_14btdl_c flux = 3.425
# Carbon yield = 0.564324002382371
# Fractions → PET=0.14, PU=0.36, PBAT=0.5
# SK_etheglycol_c flux = 1.6
# SK_terepa_c flux = 1.81
# SK_adpac_c flux = 3.19
# SK_14btdl_c flux = 3.4
# Carbon yield = 0.5632685442284826
# Fractions → PET=0.15, PU=0.35, PBAT=0.5
# SK_etheglycol_c flux = 1.625
# SK_terepa_c flux = 1.86
# SK_adpac_c flux = 3.14
# SK_14btdl_c flux = 3.375
# Carbon yield = 0.5622151773330699
# Fractions → PET=0.16, PU=0.33999999999999997, PBAT=0.5
# SK_etheglycol_c flux = 1.65
# SK_terepa_c flux = 1.9100000000000001
# SK_adpac_c flux = 3.09
# SK_14btdl_c flux = 3.3499999999999996
# Carbon yield = 0.5611638954869366
# Fractions → PET=0.17, PU=0.32999999999999996, PBAT=0.5
# SK_etheglycol_c flux = 1.675
# SK_terepa_c flux = 1.9600000000000002
# SK_adpac_c flux = 3.04
# SK_14btdl_c flux = 3.325
# Carbon yield = 0.5601146925054382
# Fractions → PET=0.18, PU=0.32, PBAT=0.5
# SK_etheglycol_c flux = 1.7
# SK_terepa_c flux = 2.01
# SK_adpac_c flux = 2.99
# SK_14btdl_c flux = 3.3
# Carbon yield = 0.5590675622283684
# Fractions → PET=0.19, PU=0.31, PBAT=0.5
# SK_etheglycol_c flux = 1.725
# SK_terepa_c flux = 2.06
# SK_adpac_c flux = 2.9400000000000004
# SK_14btdl_c flux = 3.275
# Carbon yield = 0.558022498519835
# Fractions → PET=0.2, PU=0.3, PBAT=0.5
# SK_etheglycol_c flux = 1.75
# SK_terepa_c flux = 2.1100000000000003
# SK_adpac_c flux = 2.89
# SK_14btdl_c flux = 3.25
# Carbon yield = 0.5569794952681396
# Fractions → PET=0.21, PU=0.29000000000000004, PBAT=0.5
# SK_etheglycol_c flux = 1.7750000000000001
# SK_terepa_c flux = 2.16
# SK_adpac_c flux = 2.8400000000000003
# SK_14btdl_c flux = 3.225
# Carbon yield = 0.555938546385661
# Fractions → PET=0.22, PU=0.28, PBAT=0.5
# SK_etheglycol_c flux = 1.8000000000000003
# SK_terepa_c flux = 2.21
# SK_adpac_c flux = 2.79
# SK_14btdl_c flux = 3.2
# Carbon yield = 0.5548996458087369
# Fractions → PET=0.23, PU=0.27, PBAT=0.5
# SK_etheglycol_c flux = 1.8250000000000002
# SK_terepa_c flux = 2.2600000000000002
# SK_adpac_c flux = 2.74
# SK_14btdl_c flux = 3.175
# Carbon yield = 0.5538627874975436
# Fractions → PET=0.24, PU=0.26, PBAT=0.5
# SK_etheglycol_c flux = 1.85
# SK_terepa_c flux = 2.31
# SK_adpac_c flux = 2.6900000000000004
# SK_14btdl_c flux = 3.15
# Carbon yield = 0.5528279654359783
# Fractions → PET=0.25, PU=0.25, PBAT=0.5
# SK_etheglycol_c flux = 1.875
# SK_terepa_c flux = 2.3600000000000003
# SK_adpac_c flux = 2.64
# SK_14btdl_c flux = 3.125
# Carbon yield = 0.5517951736315488
# Fractions → PET=0.26, PU=0.24, PBAT=0.5
# SK_etheglycol_c flux = 1.9
# SK_terepa_c flux = 2.41
# SK_adpac_c flux = 2.59
# SK_14btdl_c flux = 3.1
# Carbon yield = 0.5507644061152497
# Fractions → PET=0.27, PU=0.22999999999999998, PBAT=0.5
# SK_etheglycol_c flux = 1.925
# SK_terepa_c flux = 2.46
# SK_adpac_c flux = 2.54
# SK_14btdl_c flux = 3.075
# Carbon yield = 0.5497356569414541
# Fractions → PET=0.28, PU=0.21999999999999997, PBAT=0.5
# SK_etheglycol_c flux = 1.9500000000000002
# SK_terepa_c flux = 2.5100000000000002
# SK_adpac_c flux = 2.49
# SK_14btdl_c flux = 3.05
# Carbon yield = 0.5487089201877943
# Fractions → PET=0.29, PU=0.21000000000000002, PBAT=0.5
# SK_etheglycol_c flux = 1.975
# SK_terepa_c flux = 2.56
# SK_adpac_c flux = 2.4400000000000004
# SK_14btdl_c flux = 3.025
# Carbon yield = 0.5476841899550527
# Fractions → PET=0.3, PU=0.2, PBAT=0.5
# SK_etheglycol_c flux = 2.0
# SK_terepa_c flux = 2.6100000000000003
# SK_adpac_c flux = 2.39
# SK_14btdl_c flux = 3.0
# Carbon yield = 0.546661460367045
# Fractions → PET=0.31, PU=0.19, PBAT=0.5
# SK_etheglycol_c flux = 2.025
# SK_terepa_c flux = 2.66
# SK_adpac_c flux = 2.34
# SK_14btdl_c flux = 2.975
# Carbon yield = 0.5456407255705101
# Fractions → PET=0.32, PU=0.18, PBAT=0.5
# SK_etheglycol_c flux = 2.05
# SK_terepa_c flux = 2.71
# SK_adpac_c flux = 2.29
# SK_14btdl_c flux = 2.95
# Carbon yield = 0.5446219797349967
# Fractions → PET=0.33, PU=0.16999999999999998, PBAT=0.5
# SK_etheglycol_c flux = 2.075
# SK_terepa_c flux = 2.7600000000000002
# SK_adpac_c flux = 2.24
# SK_14btdl_c flux = 2.925
# Carbon yield = 0.5436052170527556
# Fractions → PET=0.34, PU=0.15999999999999998, PBAT=0.5
# SK_etheglycol_c flux = 2.1
# SK_terepa_c flux = 2.8100000000000005
# SK_adpac_c flux = 2.19
# SK_14btdl_c flux = 2.9
# Carbon yield = 0.5425904317386236
# Fractions → PET=0.35000000000000003, PU=0.14999999999999997, PBAT=0.5
# SK_etheglycol_c flux = 2.125
# SK_terepa_c flux = 2.8600000000000003
# SK_adpac_c flux = 2.1399999999999997
# SK_14btdl_c flux = 2.875
# Carbon yield = 0.5415776180299211
# Fractions → PET=0.36, PU=0.14, PBAT=0.5
# SK_etheglycol_c flux = 2.15
# SK_terepa_c flux = 2.91
# SK_adpac_c flux = 2.0900000000000003
# SK_14btdl_c flux = 2.85
# Carbon yield = 0.5405667701863361
# Fractions → PET=0.37, PU=0.13, PBAT=0.5
# SK_etheglycol_c flux = 2.1750000000000003
# SK_terepa_c flux = 2.96
# SK_adpac_c flux = 2.04
# SK_14btdl_c flux = 2.825
# Carbon yield = 0.5395578824898204
# Fractions → PET=0.38, PU=0.12, PBAT=0.5
# SK_etheglycol_c flux = 2.1999999999999997
# SK_terepa_c flux = 3.01
# SK_adpac_c flux = 1.9900000000000002
# SK_14btdl_c flux = 2.8
# Carbon yield = 0.5385509492444797
# Fractions → PET=0.39, PU=0.10999999999999999, PBAT=0.5
# SK_etheglycol_c flux = 2.225
# SK_terepa_c flux = 3.0600000000000005
# SK_adpac_c flux = 1.94
# SK_14btdl_c flux = 2.775
# Carbon yield = 0.5375459647764665
# Fractions → PET=0.4, PU=0.09999999999999998, PBAT=0.5
# SK_etheglycol_c flux = 2.25
# SK_terepa_c flux = 3.1100000000000003
# SK_adpac_c flux = 1.8900000000000001
# SK_14btdl_c flux = 2.75
# Carbon yield = 0.5365429234338752
# Fractions → PET=0.41000000000000003, PU=0.08999999999999997, PBAT=0.5
# SK_etheglycol_c flux = 2.2750000000000004
# SK_terepa_c flux = 3.16
# SK_adpac_c flux = 1.8399999999999999
# SK_14btdl_c flux = 2.725
# Carbon yield = 0.5355418195866339
# Fractions → PET=0.42, PU=0.08000000000000002, PBAT=0.5
# SK_etheglycol_c flux = 2.3000000000000003
# SK_terepa_c flux = 3.21
# SK_adpac_c flux = 1.7900000000000003
# SK_14btdl_c flux = 2.7
# Carbon yield = 0.5345426476263992
# Fractions → PET=0.43, PU=0.07, PBAT=0.5
# SK_etheglycol_c flux = 2.3249999999999997
# SK_terepa_c flux = 3.26
# SK_adpac_c flux = 1.7400000000000002
# SK_14btdl_c flux = 2.675
# Carbon yield = 0.5335454019664552
# Fractions → PET=0.44, PU=0.06, PBAT=0.5
# SK_etheglycol_c flux = 2.35
# SK_terepa_c flux = 3.3100000000000005
# SK_adpac_c flux = 1.6900000000000002
# SK_14btdl_c flux = 2.65
# Carbon yield = 0.5325500770416035
# Fractions → PET=0.45, PU=0.04999999999999999, PBAT=0.5
# SK_etheglycol_c flux = 2.375
# SK_terepa_c flux = 3.3600000000000003
# SK_adpac_c flux = 1.6400000000000001
# SK_14btdl_c flux = 2.625
# Carbon yield = 0.5315566673080635
# Fractions → PET=0.46, PU=0.03999999999999998, PBAT=0.5
# SK_etheglycol_c flux = 2.4000000000000004
# SK_terepa_c flux = 3.41
# SK_adpac_c flux = 1.59
# SK_14btdl_c flux = 2.6
# Carbon yield = 0.5305651672433693
# Fractions → PET=0.47000000000000003, PU=0.02999999999999997, PBAT=0.5
# SK_etheglycol_c flux = 2.425
# SK_terepa_c flux = 3.46
# SK_adpac_c flux = 1.54
# SK_14btdl_c flux = 2.5749999999999997
# Carbon yield = 0.5295755713462653
# Fractions → PET=0.48, PU=0.020000000000000018, PBAT=0.5
# SK_etheglycol_c flux = 2.45
# SK_terepa_c flux = 3.51
# SK_adpac_c flux = 1.4900000000000002
# SK_14btdl_c flux = 2.55
# Carbon yield = 0.5285878741366082
# Fractions → PET=0.49, PU=0.010000000000000009, PBAT=0.5
# SK_etheglycol_c flux = 2.475
# SK_terepa_c flux = 3.5600000000000005
# SK_adpac_c flux = 1.4400000000000002
# SK_14btdl_c flux = 2.525
# Carbon yield = 0.5276020701552628

# %% [markdown]
# need to correct the range of the variying fraction it doesnt reach the full fraction

# %%
import numpy as np
import pandas as pd
from cobra import Model  # only for type hints, you probably already imported your model

# TODO : CALCULATE MOL/MOL maybe flux divide it by flux

# =======================
# --- USER PARAMETERS ---
# =======================

# Composition of each polymer (fraction of each monomer)
POLYMERS = {
    "PET":  {"SK_etheglycol_c": 0.5, "SK_terepa_c": 0.5, "SK_adpac_c": 0.00, "SK_14btdl_c": 0.00},
    "PU":   {"SK_etheglycol_c": 0.25, "SK_terepa_c": 0.00, "SK_adpac_c": 0.5, "SK_14btdl_c": 0.25},
    "PBAT": {"SK_etheglycol_c": 0.00, "SK_terepa_c": 0.222,"SK_adpac_c": 0.278,"SK_14btdl_c": 0.5},
}

# Number of carbons per monomer
CARBONS = {
    'SK_etheglycol_c': 2,
    'SK_terepa_c': 8,
    'SK_adpac_c': 6,
    'SK_14btdl_c': 4
}

TOTAL_UPTAKE = 10.0       # mmol/gDW/h total uptake flux
PRODUCT_ID = "SK_bhb_c"   # product to maximize
PRODUCT_CARBONS = 4       # BHB has 4 carbons
fixed_fraction_value = 0.5 # value of the fixed polymer


# ==========================
# --- HELPER FUNCTIONS ---
# ==========================

def set_polymer_uptake(model, fractions, total_uptake=TOTAL_UPTAKE):
    """
    Apply uptake bounds for each monomer according to polymer fractions.
    fractions: dict with polymer names and their fraction of total uptake
    """
    # Reset uptake for each substrate
    uptake_dict = {met: 0.0 for met in CARBONS}
    
    # Sum contribution from each polymer
    for polymer, mix in POLYMERS.items():
        for met, coeff in mix.items():
            uptake_dict[met] += total_uptake * fractions.get(polymer, 0) * coeff
    
    # Apply to model (set lower bounds negative)
    for met, lb in uptake_dict.items():
        if lb != 0:
            rxn = model.reactions.get_by_id(met)
            rxn.bounds = (-lb, 0.0)
    return uptake_dict


def compute_carbon_yield(model, uptake_dict, product_id=PRODUCT_ID, product_carbons=PRODUCT_CARBONS):
    """
    Optimize the model for the chosen product and compute carbon yield.
    
    """
    model.objective = product_id
    sol = model.optimize()
    
    # Carbon in consumed substrates
    total_C_in = sum((-model.reactions.get_by_id(m).flux) * c
                     for m, c in CARBONS.items())
    
    # Carbon in product
    prod_flux = sol.fluxes.get(product_id, 0)
    total_C_out = prod_flux * product_carbons
    
    yield_C = total_C_out / total_C_in if total_C_in > 0 else None
    return yield_C, prod_flux

def compute_mol_yield(model, uptake_dict, product_id=PRODUCT_ID, product_carbons=PRODUCT_CARBONS):
    """
    Optimize the model for the chosen product and compute mol/mol yield.
    
    """
    model.objective = product_id
    sol = model.optimize()
    
    total_mol_in = sum((-model.reactions.get_by_id(m).flux) 
                     for m, c in CARBONS.items())
    # Carbon in product
    prod_flux = sol.fluxes.get(product_id, 0)
    total_C_out = prod_flux * product_carbons
    
    yield_mol = total_C_out / total_mol_in if total_mol_in > 0 else None
    return yield_mol, prod_flux


def sweep_polymer_ratios(model, fixed_polymer, fixed_fraction=fixed_fraction_value,
                         total_uptake=TOTAL_UPTAKE, step=0.01):
    """
    Sweep combinations where one polymer is fixed and the other two vary.
    Returns a list of dicts with results.
    """
    rows = []
    others = [p for p in POLYMERS if p != fixed_polymer]

    for var_frac in np.arange(0, fixed_fraction_value + step/2, step):  # remaining half
        fracs = {fixed_polymer: fixed_fraction}
        fracs[others[0]] = var_frac
        fracs[others[1]] = (1-fixed_fraction) - var_frac

        # Set model uptake
        uptake_dict = set_polymer_uptake(model, fracs, total_uptake)
        
        # Optimize & get carbon yield
        yield_C, prod_flux = compute_carbon_yield(model, uptake_dict)
                
        # Optimize & get mol/mol yield
        yield_mol, prod_flux = compute_mol_yield(model, uptake_dict)
        
        rows.append({
            "fixed_polymer": fixed_polymer,
            "var_polymer": others[0],
            "var_fraction": var_frac,
            "frac_PET": fracs.get("PET", 0),
            "frac_PU": fracs.get("PU", 0),
            "frac_PBAT": fracs.get("PBAT", 0),
            "mol/mol_yield": yield_mol,
            "product_flux": prod_flux
        })
    return rows


# ===========================
# --- MAIN EXECUTION ------
# ===========================

all_results = []
for fixed in POLYMERS.keys():
    print(f"Running sweep with {fixed} fixed at {fixed_fraction_value} ...")
    all_results.extend(sweep_polymer_ratios(model, fixed_polymer=fixed))

df = pd.DataFrame(all_results)
df.to_excel("251221_polymer_mixture_yield_sweep_half_inital_constrains.xlsx", index=False)

print("\nDone! Results saved to 251218_polymer_mixture_yield_sweep_half.xlsx")
# Out:
# Running sweep with PET fixed at 0.5 ...
# Running sweep with PU fixed at 0.5 ...
# Running sweep with PBAT fixed at 0.5 ...
#
# Done! Results saved to 251218_polymer_mixture_yield_sweep_half.xlsx
